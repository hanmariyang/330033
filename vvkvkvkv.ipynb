# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/jeong-yula/Desktop/streamlit/전처리통합최종.csv')

# %%
df['경력_min']
# Out:
# 0        3
# 1        5
# 2        3
# 3        6
# 4        4
#       ...
# 230    999
# 231      7
# 232      3
# 233      7
# 234      7
# Name: 경력_min, Length: 235, dtype: int64

# %%
dd=pd.read_csv('remote.csv')

# %%
dd
# Out:
#      재택여부       사이트          검색 키워드                          기업이름  \
# 0       0       원티드         데이터 분석가                         제네시스랩
# 1       0       원티드         데이터 분석가                      에어프레미아랩스
# 2       0  원티드,잡코리아         데이터 분석가                           매드업
# 3       0       원티드         데이터 분석가                      이글루코퍼레이션
# 4       0   원티드,사람인         데이터 분석가                         빗썸코리아
# ..    ...       ...             ...                           ...
# 230     1      링크드인  Data Scientist                         현대자동차
# 231     0      링크드인  Data Scientist  QuantumBlack, AI by McKinsey
# 232     0      링크드인  Data Scientist                        Boeing
# 233     1      링크드인  Data Scientist         Viva Republica (Toss)
# 234     1      링크드인  Data Scientist               Toss Bank(토스뱅크)
#
#                                              포지션이름         포지션이름 전처리  \
# 0                                   Data Scientist        데이터 사이언티스트
# ...
